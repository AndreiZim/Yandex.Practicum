# %% [markdown]
# <h1>Анализ убытков приложения ProcrastinatePRO+<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Шаг-1.-Анализ-данных-и-предобработка" data-toc-modified-id="Шаг-1.-Анализ-данных-и-предобработка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Шаг 1. Анализ данных и предобработка</a></span></li><li><span><a href="#Шаг-2.-Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Шаг-2.-Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Шаг 2. Функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функция-для-получения-профилей-пользователей" data-toc-modified-id="Функция-для-получения-профилей-пользователей-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функция для получения профилей пользователей</a></span></li><li><span><a href="#Функция-для-расчета-удержания" data-toc-modified-id="Функция-для-расчета-удержания-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функция для расчета удержания</a></span></li><li><span><a href="#Функция-для-расчета-конверсии" data-toc-modified-id="Функция-для-расчета-конверсии-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Функция для расчета конверсии</a></span></li><li><span><a href="#Функция-для-расчета-LTV-и-ROI" data-toc-modified-id="Функция-для-расчета-LTV-и-ROI-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функция для расчета LTV и ROI</a></span></li><li><span><a href="#Функция-для-сглаживания-данных" data-toc-modified-id="Функция-для-сглаживания-данных-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Функция для сглаживания данных</a></span></li><li><span><a href="#Функция-визуализации-удержания" data-toc-modified-id="Функция-визуализации-удержания-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Функция визуализации удержания</a></span></li><li><span><a href="#Функция-визуализации-конверсии" data-toc-modified-id="Функция-визуализации-конверсии-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Функция визуализации конверсии</a></span></li><li><span><a href="#Функция-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-визуализации-LTV-и-ROI-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Функция визуализации LTV и ROI</a></span></li></ul></li><li><span><a href="#Шаг-3.-Исследовательский-анализ-данных" data-toc-modified-id="Шаг-3.-Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Шаг 3. Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Профили-пользователей.-Даты-привлечения" data-toc-modified-id="Профили-пользователей.-Даты-привлечения-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Профили пользователей. Даты привлечения</a></span></li><li><span><a href="#Страны-пользователей" data-toc-modified-id="Страны-пользователей-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Страны пользователей</a></span></li><li><span><a href="#Устройства-пользователей" data-toc-modified-id="Устройства-пользователей-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Устройства пользователей</a></span></li><li><span><a href="#Рекламные-каналы" data-toc-modified-id="Рекламные-каналы-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Рекламные каналы</a></span></li></ul></li><li><span><a href="#Шаг-4.-Маркетинг" data-toc-modified-id="Шаг-4.-Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Шаг 4. Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Общие-траты-на-маркетинг" data-toc-modified-id="Общие-траты-на-маркетинг-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Общие траты на маркетинг</a></span></li><li><span><a href="#Маркетинговые-траты-на-пользователя" data-toc-modified-id="Маркетинговые-траты-на-пользователя-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Маркетинговые траты на пользователя</a></span></li></ul></li><li><span><a href="#Шаг-5.-Окупаемость-рекламы-для-привлечения-пользователей" data-toc-modified-id="Шаг-5.-Окупаемость-рекламы-для-привлечения-пользователей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Шаг 5. Окупаемость рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Общая-окупаемость-рекламы" data-toc-modified-id="Общая-окупаемость-рекламы-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Общая окупаемость рекламы</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-устройствам-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-странам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Взаимосвязь-негативных-факторов" data-toc-modified-id="Взаимосвязь-негативных-факторов-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Взаимосвязь негативных факторов</a></span></li></ul></li><li><span><a href="#Шаг-6.-Выводы" data-toc-modified-id="Шаг-6.-Выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Шаг 6. Выводы</a></span><ul class="toc-item"><li><span><a href="#Причины-неэффективности-привлечения-пользователей" data-toc-modified-id="Причины-неэффективности-привлечения-пользователей-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Причины неэффективности привлечения пользователей</a></span></li><li><span><a href="#Рекомендации-для-отдела-маркетинга-для-повышения-эффективности" data-toc-modified-id="Рекомендации-для-отдела-маркетинга-для-повышения-эффективности-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Рекомендации для отдела маркетинга для повышения эффективности</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Задача
#
# Задача для маркетингового аналитика развлекательного приложения Procrastinate Pro+. Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки. Задача — разобраться в причинах и помочь компании выйти в плюс, проанализировав лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов.

# %% [markdown]
# ## Шаг 1. Анализ данных и предобработка
# Загрузим данные о визитах, заказах и расходах в переменные, оптимизируем их для анализа.

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %%
visits, orders, costs = (pd.read_csv('/datasets/visits_info_short.csv'),
                         pd.read_csv('/datasets/orders_info_short.csv'),
                         pd.read_csv('/datasets/costs_info_short.csv'))
display(visits.head())
print(visits.info())
display(orders.head())
print(orders.info())
display(costs.head())
print(costs.info())
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
# User Id          309901 non-null int64
# Region           309901 non-null object
# Device           309901 non-null object
# Channel          309901 non-null object
# Session Start    309901 non-null object
# Session End      309901 non-null object
# dtypes: int64(1), object(5)
# ...

# %% [markdown]
# Из выведенных данных видно, что:
# - Явных пропусков в данных нет
# - Названия столбцов следует привести к "змеиному" стилю, чтобы не путаться
# - Нужно привести столбцы времени (Session Start, Session End, Event Dt, dt) к формату времени (в последнем случае - сразу к формату даты)
# - Проверить данные на наличие дубликатов

# %% [markdown]
# Начнем с названия столбцов - приведем их к нижнему регистру и заменим пробелы на нижнее подчеркивание.

# %%
visits.columns = visits.columns.str.lower().str.replace(' ', '_')
orders.columns = orders.columns.str.lower().str.replace(' ', '_')
costs.columns = costs.columns.str.lower().str.replace(' ', '_')
#проверим
display(visits.head(), orders.head(), costs.head())
# Out:
#         user_id         region   device  channel        session_start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            session_end
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
#         user_id             event_dt  revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# ...

# %% [markdown]
# Теперь приведем к datetime данные о времени (в случае со столбцом dt в cost - сразу к date).

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date
#проверим типы
print(visits.info(), orders.info(), costs.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
# user_id          309901 non-null int64
# region           309901 non-null object
# device           309901 non-null object
# channel          309901 non-null object
# session_start    309901 non-null datetime64[ns]
# session_end      309901 non-null datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
# user_id     40212 non-null int64
# event_dt    40212 non-null datetime64[ns]
# revenue     40212 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
# dt         1800 non-null object
# channel    1800 non-null object
# costs      1800 non-null float64
# ...

# %% [markdown]
# Осталось проверить наличие дубликатов

# %%
visits.duplicated().sum(), orders.duplicated().sum(), costs.duplicated().sum()
# Out:
# (0, 0, 0)

# %% [markdown]
# Дубликатов нет.
#
# Итак, названия столбцов приведены к удобному формату, столбцы времени - к правильному типу, данные проверены на отсутствие дубликатов. Можно начинать анализ, но сначала надо задать необходимые функции

# %% [markdown]
# ## Шаг 2. Функции для расчета и анализа LTV, ROI, удержания и конверсии
#
# Зададим функции:
# - get_profiles() - для получения профилей пользователей,
# - get_retention() - для расчета удержания,
# - get_conversion() - для расчета конверсии,
# - get_ltv() - для расчета LTV, CAC, ROI
# А также функции для визуализации этих метрик:
# - filter_data() - функция для сглаживания данных со скользящим средним,
# - plot_retention(),
# - plot_conversion(),
# - plot_ltv_roi() - для визуализации показателей

# %% [markdown]
# ### Функция для получения профилей пользователей

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция для расчета удержания

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчета конверсии

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчета LTV и ROI

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция для сглаживания данных

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция визуализации удержания

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция визуализации конверсии

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция визуализации LTV и ROI

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Все функции заданы, можно приступать к анализу

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# ### Профили пользователей. Даты привлечения

# %% [markdown]
# Получим профили пользователей с помощью функции get_profiles()

# %%
profiles = get_profiles(visits, orders, costs)
#проверим
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# Определим минимальную и максимальную дату привлечения пользователей

# %%
print('Минимальная дата привлечения пользователей:', profiles['dt'].min())
print('Максимальная дата привлечения пользователей:', profiles['dt'].max())
# Out:
# Минимальная дата привлечения пользователей: 2019-05-01
# Максимальная дата привлечения пользователей: 2019-10-27

# %% [markdown]
# Итак, в данных содержится информация о пользователях, привлеченных с 1 мая по 27 октября 2019 года.

# %% [markdown]
# ### Страны пользователей

# %% [markdown]
# Выясним из каких стран приходят посетители и какие страны дают больше всего платящих пользователей.

# %%
#сгруппируем профили по региону, посчитав количество пользователей и платящих пользователей
region_users = (profiles.groupby('region')
                .agg({'user_id': 'nunique', 'payer': 'sum'})
                .rename(columns = {'user_id': 'total_users', 'payer': 'total_payers'}))
#посчитаем процент платящих пользователей от всех пользователей в разрезе по странам                 
region_users['% of payers'] = (region_users['total_payers'] / region_users['total_users'] * 100).round(2)
region_users['total_payers'] = region_users['total_payers'].astype(int)
#визуализируем соотношение по странам при помощи круговой диаграммы и выведем таблицу
region_users['total_users'].plot(kind = 'pie', figsize = (10, 10), title = 'Страны пользователей', autopct='%1.2f%%')
plt.show()
region_users
# Out:
#                total_users  total_payers  % of payers
# region
# France               17450           663         3.80
# Germany              14981           616         4.11
# UK                   17575           700         3.98
# United States       100002          6902         6.90

# %% [markdown]
# В разбивке по странам можно сказать следующее:
# - 66.6% пользователей приходят из США, это самый важный рынок. Остальные 3 страны: Германия, Франция, Великобритания - занимают близкие доли по 10-12 %;
# - В США же самая высокая доля платящих пользователей - 6.9%, в то время как в остальных странах она держится на уровне около 4%

# %% [markdown]
# ### Устройства пользователей

# %% [markdown]
# Проанализируем данные в разбивке по устройствам

# %%
#сгруппируем профили по девайсу, посчитав количество пользователей и платящих пользователей
device_users = (profiles.groupby('device')
                .agg({'user_id': 'nunique', 'payer': 'sum'})
                .rename(columns = {'user_id': 'total_users', 'payer': 'total_payers'}))
#посчитаем процент платящих пользователей от всех пользователей в разрезе по платформам                
device_users['% of payers'] = (device_users['total_payers'] / device_users['total_users'] * 100).round(2)
device_users['total_payers'] = device_users['total_payers'].astype(int)
#визуализируем соотношение при помощи круговой диаграммы и выведем таблицу
device_users['total_users'].plot(kind = 'pie', figsize = (10, 10), title = 'Доли различных устройств', autopct='%1.2f%%')
plt.show()
device_users
# Out:
#          total_users  total_payers  % of payers
# device
# Android        35032          2050         5.85
# Mac            30042          1912         6.36
# PC             30455          1537         5.05
# iPhone         54479          3382         6.21

# %% [markdown]
# - Больше всего пользователи заходят в приложение с айфонов - 36.32%, следом идет андроид - 23.35%, доля Mac и PC примерно равна - чуть больше 20%.
# - При этом разброс доли платящих пользователей для разных платформ не очень большой - от 5.04 до 6.36%. На устройствах Apple он выше - 6.36% для Mac, 6.2% для Iphone, в то время как минимальный процент зафиксирован для пользователей PC - 5.04%

# %% [markdown]
# ### Рекламные каналы
#
# Теперь сгруппируем данные по рекламным каналам и выясним, какие каналы приносят больше всего платящих пользователей.

# %%
#сгруппируем профили по рекламным каналам, посчитав количество пользователей и платящих пользователей
channel_users = (profiles.groupby('channel')
                .agg({'user_id': 'nunique', 'payer': 'sum'})
                .rename(columns = {'user_id': 'total_users', 'payer': 'total_payers'}))
#посчитаем процент платящих пользователей от всех пользователей в разрезе по рекламным каналам               
channel_users['% of payers'] = (channel_users['total_payers'] / channel_users['total_users'] * 100).round(2)
channel_users['total_payers'] = channel_users['total_payers'].astype(int)
#визуализируем соотношение при помощи круговой диаграммы и выведем таблицу
channel_users['total_users'].plot(kind = 'pie', figsize = (10, 10), 
                                  title = 'Доли различных каналов привлечения клиентов', 
                                  autopct='%1.2f%%')
plt.show()
channel_users.sort_values(by='% of payers', ascending = False)
# Out:
#                     total_users  total_payers  % of payers
# channel
# FaceBoom                  29144          3557        12.20
# AdNonSense                 3880           440        11.34
# lambdaMediaAds             2149           225        10.47
# TipTop                    19561          1878         9.60
# RocketSuperAds             4448           352         7.91
# WahooNetBanner             8553           453         5.30
# YRabbit                    4312           165         3.83
# MediaTornado               4364           156         3.57
# LeapBob                    8553           262         3.06
# OppleCreativeMedia         8605           233         2.71
# organic                   56439          1160         2.06

# %% [markdown]
# - Больше всего в приложение приходит органических пользователей (37.62%), но они же платят меньше всего денег (только 2.05% от категории 'organic').
# - Лидерами по привлечению пользователей являются каналы FaceBoom (19.43%) и TipTop (13.04%). Далее идут 3 канала с долей 5.7% - OppleCreativeMedia, LeapBob, WahooNetBanner. Остальные каналы имеют долю меньше 3% каждый.
# - По проценту платящих пользователей лучше всего выглядит FaceBoom - 12.2%. Также выше 10% доля платящих у AdNonSense и lambdaMediaAds, но общее количество привлеченных через эти каналы пользователей очень мало. Для другого крупного канала - TipTop - процент платящих пользователей составляет 9.6%, что хуже, чем у FaceBoom, но в целом немало.
#
# В итоге можно констатировать, что наиболее перспективным рекламным каналом по этим данным выглядит FaceBoom - через него приходит 19.43% всех пользователей и 12.2% из них платят деньги (что является самым высоким процентом среди всех каналов). Второй по перспективности канал - TipTop - 13.04% пользователей, 9.6% из которых конвертируются в платящих пользователей. Доля органических пользователей велика - 37.62%, но они совершенно не склонны платить - только 2 процента из них становятся платными пользователями. Но выводы можно будет делать только после анализа расходов на различные каналы продвижения.

# %% [markdown]
# ## Шаг 4. Маркетинг

# %% [markdown]
# ### Общие траты на маркетинг

# %% [markdown]
# Для начала посчитаем общую сумму расходов на маркетинг и выясним, как траты распределены по источникам

# %%
print('Общие затраты на маркетинг:', profiles['acquisition_cost'].sum())
channel_cost = profiles.groupby('channel').agg({'acquisition_cost': 'sum'}).rename(columns = {'acquisition_cost': 'spent_total'})
channel_cost.plot(kind = 'pie', y = 'spent_total', figsize = (10, 10), autopct='%1.2f%%')
plt.title('Траты на различные каналы привлечения клиентов')
plt.show()
channel_cost.sort_values(by = 'spent_total', ascending = False)
# Out:
# Общие затраты на маркетинг: 105497.29999999999
#                     spent_total
# channel
# TipTop                 54751.30
# FaceBoom               32445.60
# WahooNetBanner          5151.00
# AdNonSense              3911.25
# OppleCreativeMedia      2151.25
# RocketSuperAds          1833.00
# LeapBob                 1797.60
# lambdaMediaAds          1557.60
# MediaTornado             954.48
# YRabbit                  944.22
# organic                    0.00

# %% [markdown]
# Из общих расходов на рекламу в разбивке по каналам видно, что больше всего потрачено на TipTop (51.9% от всех средств). Это, вероятно, не оптимальный выбор, поскольку конверсия в привлеченных пользователей в платящих для этого канала на 3% меньше, чем для FaceBoom, на который затрачено на 20% рекламного бюджета меньше.
#
# Кроме того видно, что доля каналов этих каналов в тратах на рекламу гораздо выше, чем доля привлеченных ими пользователей - значит их эффективность, скорее всего, не так высока, как хотелось бы. Впрочем, окончательные выводы можно будет делать, только посчитав расходы на 1 пользователя для разных платформ. Пока же посмотрим динамику рекламных расходов

# %%
channel_date_cost = profiles.pivot_table(index='dt', columns = 'channel', values='acquisition_cost', aggfunc='sum')
channel_date_cost.plot(grid=True, yticks = range(0, 650, 50), figsize=(20, 15))
plt.ylabel('Траты')
plt.xlabel('Дата привлечения')
plt.title('Динамика рекламных расходов по в разбивке по каналам привлечения')
plt.show()

# %% [markdown]
# Графики слишком неровные, применим нашу функцию filter_data со скользящим средним за 7 дней

# %%
filter_data(channel_date_cost, window = 7).plot(grid=True, yticks = range(0, 650, 50), figsize=(20, 15))
plt.ylabel('Траты')
plt.xlabel('Дата привлечения')
plt.title('Динамика рекламных расходов по в разбивке по каналам привлечения со скользящим средним в 7 дней')
plt.show()

# %% [markdown]
# На графике видно, как со второй половины мая начали расти траты на канал TipTop (судя по всему, не самый эффективный). Траты на FaceBoom, лучше всего приносящий платных пользователей, также выросли, но гораздо меньше. В тот же период снизились траты на канал AdNoNSense, который также хорошо приносит платящих пользователей. Но для окончательных выводов надо смотреть стоимость привлечения пользователя для всего приложения и в разбивке по платформам.

# %% [markdown]
# ### Маркетинговые траты на пользователя
#
# Посмотрим, сколько в среднем стоило привлечение одного пользователя из каждого источника, а также рассчитаем средний CAC в динамике на одного пользователя для всего проекта и для каждого источника трафика.

# %%
#расчитаем средний CAC по каналам
average_cac = (profiles.groupby('channel')
               .agg({'acquisition_cost': 'mean'})
               .round(2)
               .sort_values(by = 'acquisition_cost', ascending = False))
display(average_cac)
average_cac.plot(kind = "bar", figsize = (15, 10), grid = True)
plt.show()
# Out:
#                     acquisition_cost
# channel
# TipTop                          2.80
# FaceBoom                        1.11
# AdNonSense                      1.01
# lambdaMediaAds                  0.72
# WahooNetBanner                  0.60
# RocketSuperAds                  0.41
# OppleCreativeMedia              0.25
# MediaTornado                    0.22
# YRabbit                         0.22
# LeapBob                         0.21
# organic                         0.00

# %% [markdown]
# Из таблицы и графика средних маркетинговых расходов на пользователя видно, что затраты на одного пользователя, привлеченного в TipTop, значительно превосходят любые другие каналы - более чем в два раза, следом идут FaceBoom и AdNonSense. Теперь рассмотрим данные в динамике.

# %%
#посмотрим средний CAC на одного пользователя в динамике
profiles.pivot_table(
    index='dt', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(15, 10))
plt.ylabel('CAC')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС общая')
plt.show()

# а теперь построим график истории изменений CAC по каналам привлечения

profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(15, 10))
plt.ylabel('CAC')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

# %% [markdown]
# Как видно из графиков, со второй половинуы мая стоимость привлечения пользователей для канала TipTop начала расти, и росла каждый раз, когда траты на него увеличивались (пик расходов на этот канал в конце июня - начале июля, затем в начале августа). Все это увеличивало и средний САС в целом. Таким образом, канал TipTop, на который потрачено 51.9% бюджета, оказывался все более неэффективным. Для остальных каналов привлечения клиентов CAC был в целом стабилен.
#
# Таким образом, из общего анализа маркетинговых расходов видно, что расходы на TipTop, как канал привлечения клиентов, были не самыми эффективными, и их неээфективность только росла со временем

# %% [markdown]
# ## Шаг 5. Окупаемость рекламы для привлечения пользователей

# %% [markdown]
# Изучим окупаемость рекламы с помощью функции get_ltv() и визуализируем ее функцией plot_ltv_roi() - сначала общую, а потом с разбивкой по устройствам, странам и рекламным каналам. Для этого установим момент анализа - 1 ноября 2019 года и 14 дневный горизонт анализа, поскольку окупаемость должна наступать не позднее, чем через две недели

# %%
observation_date = datetime(2019, 11, 1).date()
horizon_days = 14

# %%
#исключим органический трафик из профилей
ad_profiles = profiles.query('channel != "organic"')
#а теперь из заказов
ad_orders = orders.merge(ad_profiles['user_id'], on = 'user_id', how = 'inner')
#а теперь из визитов
ad_visits = visits.merge(ad_profiles['user_id'], on = 'user_id', how = 'inner')
#проверим
display(ad_orders)
ad_visits
# Out:
#             user_id            event_dt  revenue
# 0      188246423999 2019-05-01 23:09:52     4.99
# 1      174361394180 2019-05-01 12:24:04     4.99
# 2      174361394180 2019-05-03 09:42:08     4.99
# 3      174361394180 2019-05-13 10:41:29     4.99
# 4      174361394180 2019-05-28 19:33:56     4.99
# ...             ...                 ...      ...
# 31530  136940622331 2019-10-30 22:35:59     4.99
# 31531  832315238087 2019-10-31 08:31:01     4.99
# 31532  492983055500 2019-10-31 10:43:57     4.99
# 31533  651604369137 2019-10-31 16:19:07     4.99
# 31534  168548862926 2019-10-31 22:46:19     4.99
#
# [31535 rows x 3 columns]
#              user_id         region   device             channel  \
# 0       326433527971  United States  Android              TipTop
# 1       326433527971  United States  Android              TipTop
# 2        90242400005  United States   iPhone      RocketSuperAds
# 3        90242400005  United States   iPhone             YRabbit
# ...

# %% [markdown]
# ### Общая окупаемость рекламы

# %% [markdown]
# Посмотрим на общую окупаемость для рекламных каналов (без органического трафика)

# %%
#найдем показатели LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(ad_profiles, 
                                                                      ad_orders, 
                                                                      observation_date, 
                                                                      horizon_days)
#визуализируем их с помощью plot_ltv_roi()
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# - Реклама не окупается даже через две недели, показатель ROI около 0.8.
#
# - При этом так было не всегда, на графике динамики ROI видно, что поначалу этот показатель был значительно выше уровня окупаемости, но к июню - июлю стал стабильно меньше этого уровня.
#
# - При этом динамика LTV по всему периоду анализа было волноообразна, но стабильна - в основном в пределах 0.8-1
#
# - Причина падения ROI - в росте затрат на привлечение одного человека CAC.

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    ad_profiles, ad_orders, observation_date, horizon_days)
retention_raw, retention_grouped, retention_history = get_retention(
    ad_profiles, ad_visits, observation_date, horizon_days)

plot_conversion(conversion_grouped, conversion_history, horizon_days)
plt.show()
plot_retention(retention_grouped, retention_history, horizon_days)
plt.show()

# %% [markdown]
# Из графиков видно:
# - в целом удержание платящих пользователей гораздо выше, чем неплатящих;
# - динамика конверсии за исследуемый период довольно сильно менялась, но все значения в основном в коридоре 7.5 - 8.5 %
#
# Посмотрим, с какими причинами могут быть связаны такие показатели - проанализируем их в разбивке по устройствам, странам и рекламным каналам

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по устройствам

# %%
#найдем показатели LTV и ROI в разбивке по устройствам
dimensions = ['device']
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(ad_profiles, 
                                                                      ad_orders, 
                                                                      observation_date, 
                                                                      horizon_days, dimensions = dimensions)
#визуализируем их с помощью plot_ltv_roi()
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# - В разбивке по устройствам видно, что лучше окупаются только пользователи на PC, пользователи на Android не окупаются, хотя и близки к порогу окупаемости (ок. 0.9), а вот на устройствах Apple пользователям до окупаемости еще дальше (ок. 0.7).
# - Именно для пользователей Mac и iPhone больше всего взлетели затраты на привлечение в июне.
# - Динамика ROI в целом повторяет общую картинку - в начале периода окупаемость была выше.
#
# Посмотрим теперь на конверсию и удержание в этой же разбивке

# %%
# смотрим конверсию с разбивкой по устройствам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    ad_profiles, ad_orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Конверсия пользователей PC значительно меньше, чем для других устройств, но эти пользователи значительно дешевле, поэтому продолжают окупаться.

# %%
# смотрим удержание с разбивкой по устройствам

retention_raw, retention_grouped, retention_history = get_retention(
    ad_profiles, ad_visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# - На графиках удержания видно, что для PC удержание несколько выше - вероятно, в этом причина окупаемости для менее конвертируемых пользователей PC.
# - При этом в динамике видно, что в мае - июне удержание для пользователей PC было больше, а потом в целом сравнялась с другими устройствами. Хотя вообще для всех типов устройтсв характерен очень большой разброс в графиках удержания

# %% [markdown]
# В итоге:
# - Можно сказать, что в разбивке по устройствам окупаются  только пользователи PC. Совсем плоха ситуация для пользователей устройств Apple, которых большинство, на уровне 0.7. Чуть получше, но тоже ниже уровня окупаемости - Android.
# - При этом конверсия для пользователей PC самая низкая, но эта когорта все равно остается прибыльной за счет низкой стоимости привлечения и большего удержания.
# - Стоимость привлечения пользователей Iphone, Mac и затем Android в определенный момент (с июня) стала слишком высока, что не позволяет им окупаться.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по странам

# %%
#найдем показатели LTV и ROI в разбивке по странам
dimensions = ['region']
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(ad_profiles, 
                                                                      ad_orders, 
                                                                      observation_date, 
                                                                      horizon_days, dimensions = dimensions)
#визуализируем их с помощью plot_ltv_roi()
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# В разбивке по странам видно, что пользователи из США, несмотря на высокий LTV, не окупаются (ROI меньше 1). При этом поначалу, до начала июня, ROI для пользователей США был неплох, но затем резко упал из-за роста стоимости привлечения одного пользователя (как видно из анализа маркетинговых расходов, это связано с ростом расходов на TipTop). Интересно, что в это же время СAC для пользоватлей из других стран снизился). Посмотрим на конверсию и удержание.

# %%
# смотрим конверсию и удержание с разбивкой по странам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    ad_profiles, ad_orders, observation_date, horizon_days, dimensions=dimensions
)
retention_raw, retention_grouped, retention_history = get_retention(
    ad_profiles, ad_visits, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)
plt.show()
plot_retention(retention_grouped, retention_history, horizon_days)
plt.show()

# %% [markdown]
# Пользователи из США конвертируются очень хорошо - в 2 раза лучше, чем пользователи из других стран. Но при этом и удержание для американцев гораздо ниже, чем для других стран, т.е. они не остаются в приложении, что, на фоне высокой стоимости привлечения, не позволяет окупаться трафику из США

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по рекламным каналам

# %%
#найдем показатели LTV и ROI в разбивке по рекламным каналам
dimensions = ['channel']
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(ad_profiles, 
                                                                      ad_orders, 
                                                                      observation_date, 
                                                                      horizon_days, dimensions = dimensions)
#визуализируем их с помощью plot_ltv_roi()
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# В разбивке по рекламным каналам видно, что главные каналы - FaceBoom и TipTop, на которые расходуется более 80% всех средств, стабильно не окупаются. При этом затраты на привлечение пользователя в TipTop вообще постоянно растут.

# %%
# смотрим конверсию и удержание с разбивкой по каналам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    ad_profiles, ad_orders, observation_date, horizon_days, dimensions=dimensions
)
retention_raw, retention_grouped, retention_history = get_retention(
    ad_profiles, ad_visits, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)
plt.show()
plot_retention(retention_grouped, retention_history, horizon_days)
plt.show()

# %% [markdown]
# Из графиков конверсии и удержания видно, что FaceBoom, несмотря на высокую конверсию, обладает крайне низким удержанием (как и AdNonSense). Именно это значительно снижает окупаемость этого канала. Т.е. для TipTop реклама дорогая, а для FaceBoom - неэффективная, поскольку приводит пользователей, не задерживающихся в приложении.

# %% [markdown]
# Таким образом, мы выявили, что реклама приложения в целом не окупается. И это может быть связано с несколькими факторами:
# - не окупается реклама для пользователей всех устройств, кроме PC (но особенно iPhone и Мас) в силу высокой стоимости привлечения клиентов для этих устройств
# - не окупается реклама для пользователей из США, которые составляют 2/3 всех пользователей в силу их низкого удержания
# - не окупается реклама для двух главных каналов привлечения TipTop и FaceBoom, поскольку в первом постоянно растет стоимость привлечения клиентов, а во втором низкий показатель удержания клиентов.

# %% [markdown]
# ### Взаимосвязь негативных факторов
#
# В связи с выявленными закономерностями целесообразно будет посмотреть, не взаимосвязаны ли между собой показатели, т.е. определить для США и других стран доли устройств Apple и каналов привлечения TipTop и FaceBoom. Возьмем только неорганические профили

# %%
ad_profiles.query('region == "United States"').groupby('device').agg({'user_id': 'nunique'}).rename(columns = {'user_id': 'users_total'}).plot(kind = 'pie', y = 'users_total', figsize = (10, 10), autopct='%1.2f%%')
plt.title('Устройства пользователей в США')
plt.show()
ad_profiles.query('region != "United States"').groupby('device').agg({'user_id': 'nunique'}).rename(columns = {'user_id': 'users_total'}).plot(kind = 'pie', y = 'users_total', figsize = (10, 10), autopct='%1.2f%%')
plt.title('Устройства пользователей не в США')
plt.show()

# %% [markdown]
# На диаграммах видно, что в США доля пользователей iPhone и Mac, для которых стоимость привлечения клиента очень высока - почти 70%, в то время как в Европе превалируют PC и Android, для пользователей которых CAC ниже.

# %%
ad_profiles.query('region == "United States"').groupby('channel').agg({'user_id': 'nunique'}).rename(columns = {'user_id': 'users_total'}).plot(kind = 'pie', y = 'users_total', figsize = (10, 10), autopct='%1.2f%%')
plt.title('Рекламные каналы в США')
plt.show()
ad_profiles.query('region != "United States"').groupby('channel').agg({'user_id': 'nunique'}).rename(columns = {'user_id': 'users_total'}).plot(kind = 'pie', y = 'users_total', figsize = (10, 10), autopct='%1.2f%%')
plt.title('Рекламные каналы не в США')
plt.show()

# %% [markdown]
# Именно на американский рынок работают два самых крупных канала привлечения клиентов TipTop и FaceBoom. Оба они не окупаются в силу большой стоимости привлечения у  TipTop и плохо удержания у FaceBoom.

# %%
region_device = ad_profiles.pivot_table(index = 'device', columns = 'region', values = 'user_id', aggfunc = 'nunique')
region_device['other'] = region_device['France'] + region_device['Germany'] + region_device['UK']
#region_device = region_device
region_device.drop(columns = ['France', 'Germany', 'UK']).plot(kind = 'bar', figsize = (15, 10), grid = True)
plt.show()

# %% [markdown]
# ## Шаг 6. Выводы

# %% [markdown]
# ### Причины неэффективности привлечения пользователей

# %% [markdown]
# Таким образом, в ходе исследования удалось выяснить, что реклама приложения в целом неэфективна.
#
# Это может быть связано со следующими факторами:
# - не окупается реклама для пользователей Android и, в особенности, для iPhone и Мас в силу высокой стоимости привлечения клиентов для этих устройств
# - не окупается реклама для пользователей из США, которые составляют 2/3 всех пользователей в силу их низкого удержания
# - не окупается реклама для двух главных каналов привлечения TipTop и FaceBoom, поскольку в первом постоянно растет стоимость привлечения клиентов, а во втором низкий показатель удержания клиентов
#
# Причем эти факторы взаимосвязаны - американская аудитория гораздо больше пользуется устройствами Apple (70% пользователей), чем пользователи из Европы (около 30% пользователей). Именно на американский рынок направлены каналы привлечения клиентов TipTop и FaceBoom.

# %% [markdown]
# ### Рекомендации для отдела маркетинга для повышения эффективности

# %% [markdown]
# Рекомендации для отдела маркетинга могут состоять в следующем:
# - пересмотреть рекламные стратегии для США - текущие рекламные каналы "съедают" львиную долю бюджета, но приносят недостаточно платящих пользователей (особенно это касается TipTop, стоимость которого для компании постоянно растет и FaceBoom, где низкий показатель удержания клиента)
# - больше ориентироваться на европейский рынок, а значит на другие рекламные каналы (к примеру, OppleCreativeMedia или AdNonSense) и, возможно, на другие типы устройств, в частности PC
