# %% [markdown]
# <h1>Оглавление<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1">Описание проекта</a></span><ul class="toc-item"><li><span><a href="#Цель-исследования" data-toc-modified-id="Цель-исследования-1.1">Цель исследования</a></span></li><li><span><a href="#Изучение-общей-информации" data-toc-modified-id="Изучение-общей-информации-1.2">Изучение общей информации</a></span><ul class="toc-item"><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2.1">Описание данных</a></span></li><li><span><a href="#Общая-информация" data-toc-modified-id="Общая-информация-1.2.2">Общая информация</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.3">Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Названия-столбцов" data-toc-modified-id="Названия-столбцов-1.3.1">Названия столбцов</a></span></li><li><span><a href="#Обработка-пропусков-и-изменение-типов-данных" data-toc-modified-id="Обработка-пропусков-и-изменение-типов-данных-1.3.2">Обработка пропусков и изменение типов данных</a></span><ul class="toc-item"><li><span><a href="#Название-и-жанр" data-toc-modified-id="Название-и-жанр-1.3.2.1">Название и жанр</a></span></li><li><span><a href="#Год-релиза" data-toc-modified-id="Год-релиза-1.3.2.2">Год релиза</a></span></li><li><span><a href="#Оценки" data-toc-modified-id="Оценки-1.3.2.3">Оценки</a></span></li><li><span><a href="#Рейтинг" data-toc-modified-id="Рейтинг-1.3.2.4">Рейтинг</a></span></li></ul></li><li><span><a href="#Суммарные-продажи-во-всех-регионах" data-toc-modified-id="Суммарные-продажи-во-всех-регионах-1.3.3">Суммарные продажи во всех регионах</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-1.4">Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Годы-выпуска" data-toc-modified-id="Годы-выпуска-1.4.1">Годы выпуска</a></span></li><li><span><a href="#Платформы" data-toc-modified-id="Платформы-1.4.2">Платформы</a></span></li><li><span><a href="#Актуальные-данные" data-toc-modified-id="Актуальные-данные-1.4.3">Актуальные данные</a></span><ul class="toc-item"><li><span><a href="#Актуальные-платформы" data-toc-modified-id="Актуальные-платформы-1.4.3.1">Актуальные платформы</a></span></li><li><span><a href="#Анализ-глобальных-продаж-в-разбивке-по-платформам" data-toc-modified-id="Анализ-глобальных-продаж-в-разбивке-по-платформам-1.4.3.2">Анализ глобальных продаж в разбивке по платформам</a></span></li><li><span><a href="#Влияние-отзывов" data-toc-modified-id="Влияние-отзывов-1.4.3.3">Влияние отзывов</a></span></li><li><span><a href="#Жанры" data-toc-modified-id="Жанры-1.4.3.4">Жанры</a></span></li></ul></li></ul></li><li><span><a href="#Региональные-предпочтения" data-toc-modified-id="Региональные-предпочтения-1.5">Региональные предпочтения</a></span><ul class="toc-item"><li><span><a href="#Платформы" data-toc-modified-id="Платформы-1.5.1">Платформы</a></span></li><li><span><a href="#Жанры" data-toc-modified-id="Жанры-1.5.2">Жанры</a></span></li><li><span><a href="#Влияние-рейтинга-ESRB" data-toc-modified-id="Влияние-рейтинга-ESRB-1.5.3">Влияние рейтинга ESRB</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-1.6">Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Рейтинги-платформ-Xbox-One-и-PC" data-toc-modified-id="Рейтинги-платформ-Xbox-One-и-PC-1.6.1">Рейтинги платформ Xbox One и PC</a></span></li><li><span><a href="#Рейтинги-жанров-Action-и-Sports" data-toc-modified-id="Рейтинги-жанров-Action-и-Sports-1.6.2">Рейтинги жанров Action и Sports</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.7">Вывод</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Описание проекта

# %% [markdown]
# Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании для интернет-магазина игр
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# ## Цель исследования

# %% [markdown]
# На основании имеющихся данных о продажах игр, оценках пользователей и экспертов, жанрах и платформах, выявить определяющие успешность игры закономерности

# %% [markdown]
# ## Изучение общей информации

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Name — название игры
#
# Platform — платформа
#
# Year_of_Release — год выпуска
#
# Genre — жанр игры
#
# NA_sales — продажи в Северной Америке (миллионы проданных копий)
#
# EU_sales — продажи в Европе (миллионы проданных копий)
#
# JP_sales — продажи в Японии (миллионы проданных копий)
#
# Other_sales — продажи в других странах (миллионы проданных копий)
#
# Critic_Score — оценка критиков (максимум 100)
#
# User_Score — оценка пользователей (максимум 10)
#
# Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Данные за 2016 год могут быть неполными.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats as st
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Общая информация

# %% [markdown]
# Посмотрим в общем на датасет

# %%
df=pd.read_csv('/datasets/games.csv')
#посмотрим информацию о таблице
print(df.info())
#посчитаем количество пропусков по столбцам
print(df.isna().sum())
#посмотрим как выглядит сама таблица
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# Name               16713 non-null object
# Platform           16715 non-null object
# Year_of_Release    16446 non-null float64
# Genre              16713 non-null object
# NA_sales           16715 non-null float64
# EU_sales           16715 non-null float64
# JP_sales           16715 non-null float64
# Other_sales        16715 non-null float64
# Critic_Score       8137 non-null float64
# User_Score         10014 non-null object
# Rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB
# None
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64
# ...

# %% [markdown]
# Уже по обзору данных можно заметить, что:
# - Названия столбцов нужно будет привести к нижнему регистру
# - В некоторых столбцах есть пропуски:
#     - по два в Name и Genre. Вероятнее всего, это одни и те же строки. Коль скоро название игры в данной таблице - по сути аналог ID, и их всего 2, их можно будет удалить, предварительно проверив, что пропуски действительно в тех же строках.
#     - Есть некоторое количество пропусков в данных о годе релиза. Тут ничем заполнить нельзя
#     - Много пропусков в столбцах оценок
# - Годы релиза в формате float - должны быть приведены к int или date
# - Оценка пользователя должна быть приведена к типу float

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Названия столбцов

# %% [markdown]
# Для начала приведем названия столбцов к нижнему регистру

# %%
df.columns = df.columns.str.lower()
#проверим
df.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# ### Обработка пропусков и изменение типов данных

# %% [markdown]
# #### Название и жанр

# %% [markdown]
# Удостоверимся, что по 2 пропуска в названии и жанры - это одни и те же строки

# %%
df.query('name.isna()')
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# Да, так и есть, причем обе игры 93 года и на одной платформе. Но это неважно, особенно учитывая отсуствие рейтингов и минимальные объемы продаж для второй. Их можно просто удалить

# %%
df = df[(~df['name'].isna())].reset_index(drop=True)
#проверим
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16713 entries, 0 to 16712
# Data columns (total 11 columns):
# name               16713 non-null object
# platform           16713 non-null object
# year_of_release    16444 non-null float64
# genre              16713 non-null object
# na_sales           16713 non-null float64
# eu_sales           16713 non-null float64
# jp_sales           16713 non-null float64
# other_sales        16713 non-null float64
# critic_score       8137 non-null float64
# user_score         10014 non-null object
# rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# #### Год релиза

# %% [markdown]
# Год релиза отсутствует для 269 записей. Это немного, меньше 2%. Вычислить эти данные нeвозможно, а они нам очень пригодятся при анализе. Кроме того, пока есть пропуски, нельз перевести года из float к формату даты, что было бы желательно. Посмотрим, какие у нас вообще есть года может есть какая-то закономерность для этих записей. Может быть, пропуски для одной платформы или одного жанра.

# %%
#посмотрим на столбец 'year_of_release'.
print(df['year_of_release'].describe())
#проверим, сколько жанров в играх с пропущенными годами
print('Жанры для игр без года релиза:\n', df.query('year_of_release.isna()')['genre'].value_counts())
#и проверим сколько платформ
print('Платформы для игр без года релиза:\n', df.query('year_of_release.isna()')['platform'].value_counts())
# Out:
# count    16444.000000
# mean      2006.486256
# std          5.875525
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2016.000000
# Name: year_of_release, dtype: float64
# Жанры для игр без года релиза:
#  Action          62
# Sports          42
# Misc            29
# Shooter         27
# Racing          23
# Role-Playing    17
# Simulation      16
# Fighting        12
# Puzzle          11
# Adventure       10
# Platform        10
# Strategy        10
# Name: genre, dtype: int64
# Платформы для игр без года релиза:
#  Wii     34
# PS2     34
# DS      30
# X360    30
# PS3     25
# XB      21
# 2600    17
# PC      17
# PSP     16
# GC      14
# GBA     11
# 3DS      8
# PS       7
# N64      3
# GB       1
# PSV      1
# Name: platform, dtype: int64

# %% [markdown]
# Годы от 1980 до 2016. Пропущенные значения есть для разных платформ и жанров. Учитывая небольшой в целом процент, можно просто удалить данные без годов.

# %%
df = df[(~df['year_of_release'].isna())].reset_index(drop=True)
#проверим
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16444 entries, 0 to 16443
# Data columns (total 11 columns):
# name               16444 non-null object
# platform           16444 non-null object
# year_of_release    16444 non-null float64
# genre              16444 non-null object
# na_sales           16444 non-null float64
# eu_sales           16444 non-null float64
# jp_sales           16444 non-null float64
# other_sales        16444 non-null float64
# critic_score       7983 non-null float64
# user_score         9839 non-null object
# rating             9768 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Теперь годы можно вывести из float. Формат datetime нам тут особо не понадобится, только значения годов, поэтому можно просто привести к int

# %%
df['year_of_release'] = df['year_of_release'].astype(int)
#проверим
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16444 entries, 0 to 16443
# Data columns (total 11 columns):
# name               16444 non-null object
# platform           16444 non-null object
# year_of_release    16444 non-null int64
# genre              16444 non-null object
# na_sales           16444 non-null float64
# eu_sales           16444 non-null float64
# jp_sales           16444 non-null float64
# other_sales        16444 non-null float64
# critic_score       7983 non-null float64
# user_score         9839 non-null object
# rating             9768 non-null object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# #### Оценки

# %% [markdown]
# Пропуски в столбцах оценок вряд ли можно чем-то заполнить - они зависят главным образом от качества самой игры. Вполне можно представить ситуацию, что игра никак не оценена. Оценки критиков по 100-бальной шкале можно было бы привести к int, если убрать пропуски, но это не имеет практического смысла, а вот оценки пользователей надо перевести в float. Сначала разберемся, какие значения вообще бывают.

# %%
df['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %% [markdown]
# Как, в общем, и ожидалось, значения числовые, кроме одного - 'tbd'. Посмотрим, что это за значение, сколько таких значений. Посмотрим, не зависит ли оно, например, от года, платформы или жанра. Для этого построим столбчатые диаграммы.

# %%
print('Всего случаев tbd:', len(df.query('user_score == "tbd"')))
(df.query('user_score == "tbd"').groupby('year_of_release').agg({'name': 'count'}).
 rename(columns = {'name':'total_games_tbd'}).plot(kind = 'bar', grid = True, figsize = (15, 6)))
plt.show()
(df.query('user_score == "tbd"').groupby('platform').agg({'name': 'count'}).
 rename(columns = {'name':'total_games_tbd'}).plot(kind = 'bar', grid = True, figsize = (15, 6)))
plt.show()
(df.query('user_score == "tbd"').groupby('genre').agg({'name': 'count'}).
 rename(columns = {'name':'total_games_tbd'}).plot(kind = 'bar', grid = True, figsize = (15, 6)))
plt.show()
# Out:
# Всего случаев tbd: 2376

# %% [markdown]
# Всего случаев tbd 2376. Это очень много - больше 20% от всех известных оценок пользователей.
#
# Никакой конкретной закономерности выделить нельзя, хотя на графике по годам видно, что большая часть игр tbd - до 2012 года. Для нас более актуальными будут более поздние данные - ведь анализ нужно проводить для актуальных платформ. Можно предположить, что с 2012 года как-то изменилась система оценивания, что позволило пользователям легче оценивать игры или легче собирать такие оценки. Простой поисковый [запрос](https://www.google.com/search?q=tbd&oq=tbd&aqs=chrome..69i57j0i433i512j0i512l8.771j0j15&sourceid=chrome&ie=UTF-8) показывает, что это может быть аббревиатура to be determined - требует уточнения. И такое объяснение похоже на правду: чем раньше - тем больше игр с оценками tbd (сложнее было собирать и оценивать - не у всех была возможность просто поставить завездочки на какой-нибудь онлайн-платформе), но с определенного момента назад процент tbd начинает падать, потому что и количество игр было меньше и система оценивания не так сложилась. Для нас, по сути, tbd можно приравнять к NaN. Это, конечно, увеличит число пропусков в и без того не самом полном столбце оценок. Но, во-первых, за последние, самые актуальные годы, 'tbd' не так уже много, а, во-вторых, другого варианта кажется и нет.

# %%
df['user_score'] = df['user_score'].replace('tbd', np.NaN)
#проверим
print('Пропусков должно быть:', len(df) - 9839 + 2376)
print('Фактически:', len(df.query('user_score.isna()')))
# Out:
# Пропусков должно быть: 8981
# Фактически: 8981

# %% [markdown]
# Теперь можно привести оценки к типу float.

# %%
df['user_score'] = df['user_score'].astype(float)
#проверим
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16444 entries, 0 to 16443
# Data columns (total 11 columns):
# name               16444 non-null object
# platform           16444 non-null object
# year_of_release    16444 non-null int64
# genre              16444 non-null object
# na_sales           16444 non-null float64
# eu_sales           16444 non-null float64
# jp_sales           16444 non-null float64
# other_sales        16444 non-null float64
# critic_score       7983 non-null float64
# user_score         7463 non-null float64
# rating             9768 non-null object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# #### Рейтинг

# %% [markdown]
# Посмотрим на пропуске в рейтинге. Во-первых, какие вообще значения там есть.

# %%
df['rating'].value_counts(dropna = False)
# Out:
# NaN     6676
# E       3921
# T       2905
# M       1536
# E10+    1393
# EC         8
# K-A        3
# RP         1
# AO         1
# Name: rating, dtype: int64

# %% [markdown]
# Это качественные показатели, зависящие от самой игры.Пропуски тут ничем не заполнить.

# %% [markdown]
# ### Суммарные продажи во всех регионах

# %% [markdown]
# Теперь посчитаем суммарные продажи

# %%
df['total_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['other_sales']
#проверим
df.sample(10)
# Out:
#                                                name platform  year_of_release  \
# 5938                                 FIFA Soccer 13      3DS             2012
# 6258                               Magical Vacation      GBA             2001
# 4195                          Silent Hill: Downpour      PS3             2012
# 2600                        Goldeneye 007: Reloaded      PS3             2011
# 10939  Momu-chan Diet Wii: Figurobics by Chon Dayon      Wii             2010
# 12021                                      Destrega       PS             1998
# 6052     Pirates of the Caribbean: Dead Man's Chest      PSP             2006
# 7046                                 Ford vs. Chevy      PS2             2005
# 12295                         Shining Force Feather       DS             2009
# 15193             Jake Hunter: Detective Chronicles       DS             2008
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# ...

# %% [markdown]
# Все данные предварительно обработаны, можно приступать к анализу.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Годы выпуска

# %% [markdown]
# Посмотрим, сколько игр выпускалось в какие годы

# %%
games_per_year = df.groupby('year_of_release').agg({'name': 'count'}).rename(columns = {'name':'total'})
games_per_year.plot(kind = 'bar', grid = True, figsize = (15, 6))
plt.show()
display(games_per_year)
# Out:
#                  total
# year_of_release
# 1980                 9
# 1981                46
# 1982                36
# 1983                17
# 1984                14
# 1985                14
# 1986                21
# 1987                16
# 1988                15
# 1989                17
# 1990                16
# 1991                41
# 1992                43
# 1993                60
# 1994               121
# 1995               219
# 1996               263
# 1997               289
# 1998               379
# 1999               338
# 2000               350
# 2001               482
# 2002               829
# 2003               775
# 2004               762
# 2005               939
# 2006              1006
# 2007              1197
# 2008              1427
# 2009              1426
# 2010              1255
# 2011              1136
# 2012               653
# 2013               544
# 2014               581
# 2015               606
# 2016               502

# %% [markdown]
# Пик количества выпущенных игр пришелся на 2008 - 2009 годы (1427 и 1426 соотвественно). Затем количество снижается, и с 2012 по 2016 стабильно - в пределах 500-650 в год (правда из условия известно, что за 2016 данные неполные). Вероятнее всего, именно эти годы нас и будут интересовать, потому что чем раньше год, тем больше игр для уже неактуальных платформ. Теперь посмотрим данные в разрезе по платформам.

# %% [markdown]
# ### Платформы

# %% [markdown]
# Для начала просто взгялнем на количество игр, выпущенных для разных платформ

# %%
df.groupby('platform').agg({'name': 'count'}).rename(columns = {'name':'total'}).plot(kind = 'bar', grid = True, figsize = (15, 6))
plt.show()

# %% [markdown]
# Количество игр, выпущенных для платформ, очень разное. При это большое количество игр не означает важность для нашего анализа, поскольку платформа может быть давно устаревшей - это касается и самых массовых PS2 и DS. Кроме того, нам важнее одна игра, проданная в 10 млн.копий, чем 10 игр, проданные в 1000 копий каждая. Посмотрим данные по платформам в разрезе количества продаж.

# %%
platform_sales = df.groupby('platform').agg({'total_sales': 'sum'})
platform_sales.plot(kind = 'bar', grid = True, yticks=range(0, 1100, 100), figsize = (15, 10))
plt.show()

# %% [markdown]
# Очевидно, что существуют совсем "карликовые" по количеству продаж платформы и лидеры рынка. Отберем только те, у которых суммарное количество продаж больше 200 млн. и построим для них распределение по годам

# %%
#Найдем нужные платформы
top_platforms = platform_sales.query('total_sales > 200').index.tolist()
#построим график
(df.query('platform in @top_platforms').pivot_table(index='year_of_release', columns = 'platform', values='total_sales', aggfunc='sum')
 .plot(grid=True,  style = 'o-', xticks = range(1982, 2016, 1), figsize=(17, 10)))
plt.show()

# %% [markdown]
# На графике отлично видно, что срок жизни одной платформы составляет, в среднем, 8-10 лет. Есть платформы, существовавшие меньше (вплоть до 5) и чуть больше (11 - 12 лет), но в целом платформа появляется, продажи игр для нее достигают пика через 4-6 лет, а затем снижаются из-за появления новых игровых платформ и устаревания. Единственное исключение, разумеется, PC, но это, по сути и не платформа, а постоянно эволюционирующий отдельный класс.
#
# Из графика можно увидеть платформы, ответственные за определенные пики в продажах по годам. Так, небольшие пики 1998 и 2002 года явно связаны с PS и PS2, а самый большой пик 2008-2009 года  - с Wii, Xbox 360, PSP и, частично, PS3. По сути, можно отследить поколения консолей.
#
# Этот график построен для платформ, продажи для которых уже достигли 200 млн.копий, поэтому в нем, возможно, нет только появляющихся, растущих, самых перспективных платформ, которые и будут, в том числе, нам нужны. Кроме того, надо учитывать, что данные за 2016 год неполные, чем и иожет быть вызвана обманчиво снижающаяся динамика PS4, к примеру.
#
# Можно сделать вывод, что актуальными для нас будут являться данные за последние 5 лет - половину жизненного цикла платформы, ведь нам нужны те платформы, которые имеют перспективы: еще находятся на пике или растут. Если взять больше, то мы зацепим предыдущие поколения, которые уже совсем сошли на нет, если меньше - то не войдут уже снижающиеся, но еще недавно мощные платформы, типа PS3 и Xbox 360.

# %% [markdown]
# ### Актуальные данные

# %% [markdown]
# Выделим из наших данных актуальные: с 2012 по 2016 год

# %%
df_actual = df.query('year_of_release > 2011')
df_actual.sample(10)
# Out:
#                                                     name platform  \
# 10955                           Might & Magic Heroes VII       PC
# 839                                      Just Dance 2015      Wii
# 5931   Senran Kagura Shinovi Versus: Sh?jo-tachi no S...      PSV
# 5999                  Hot Shots Golf: World Invitational      PS3
# 77                                               FIFA 16      PS4
# 14610   Nekketsu Kouha Kunio-Kun SP: Rantou Kyousoukyoku      3DS
# 13918                                XBLAZE Code: Embryo      PS3
# 600                                        Madden NFL 13      PS3
# 11807                                        Lost Heroes      PSP
# 11783                   Magi: The Labyrinth of Beginning      3DS
#
#        year_of_release         genre  na_sales  eu_sales  jp_sales  \
# 10955             2015      Strategy      0.00      0.08      0.00
# 839               2014          Misc      0.99      0.85      0.00
# ...

# %% [markdown]
# #### Актуальные платформы

# %% [markdown]
# Посмотрим, какие платформы являются потенциально прибыльными. Построим график, аналогичный тому, что мы строили для самых больших по количеству продаж платформ в общем датасете

# %%
(df_actual.pivot_table(index='year_of_release', columns = 'platform', values='total_sales', aggfunc='sum')
 .plot(grid=True,  style = 'o-', xticks = range(2012, 2016, 1), yticks = range(0, 110, 5), figsize=(15, 15)))
plt.show()

# %% [markdown]
# Данные за 2016 год неполные, это надо учитывать, лучше ориентироваться на 2015 и общую динамику. На графике видно:
#
# - Самые перспективные, потенциально прибыльные платформы - это PlayStation 4 и Xbox One. Обе находятся в растущей фазе цикла: появились в 2013 и растут. За 2016 год, вероятнее всего, после подведения итогов тоже будет рост.
#
# - Видно, как в 2013 году графики продаж PS4 и Xbox One пересекают ниспадающие графики ихи предшественников PS3 и X360. Эти консоли уже бесперспективны - им на смену уже пришло новое поколение. Но, вероятно, их много у пользователей.
#
# - Также бесперспективны отжившие свое DS, PSP и Wii
#
# - Пришедшая на смену Wii Wii U также уже находится во второй половине жизненного цикла, объем продаж для нее начал снижаться
#
# - Доля персональных компьютеров довольно стабильна, хотя и снижается. В любом случае, PC с рынка не исчезнет.
#
# - Особняком стоят портативные консоли: 3DS и PSV. Они имеют особый форм фактор, их графики выглядят по-другому, с более плавными изменениями по годам. И хотя количество продаж для Nintendo 3DS в целом значительно больше, оно снижается в течении 3х лет, в то время как для PS Vita остается относительно стабильным с небольшим снижением.

# %% [markdown]
# #### Анализ глобальных продаж в разбивке по платформам

# %% [markdown]
# Построим boxplot по глобальным продажам игр в разбивке по платформа

# %%
df_actual.boxplot(column = 'total_sales', by = 'platform', figsize = (15, 10))
plt.ylim(0, 2.0)
# Out:
# (0, 2.0)

# %% [markdown]
# - На графике видно, что медианы продаж для всех платформ (кроме Хbox 360) лежат в пределах до 250 тыс.копий.
#
# - При этом разброс нормальных значений, указывающий, в данном случае на емкость рынка для одной игры на конкретной платформе, очень разный. Здесь есть условно две группы:
#     - Для портативных консолей (DS, PSP, PSV, в меньшей степени 3DS) и PC - он в пределах от 200 (PSP) до 700 (3DS) тыс.копий. Медианные значения в рамках 100 тыс.копий и менее, а 50% игр не достигают продаж в 200 тыс. копий (кроме PC и 3 DS - для них показатели чуть побольше).
#     - Для "больших" платформ семейств PlayStation, Xbox и Wii разброс значений, а, значит, и оценка емкости рынка гораздо выше. Медианные значения продаж для одной игры ближе к 200 тыс. копий, а в случае с Xbox 360 - даже выше 250 тыс. При этом верхняя граница нормальных значений продаж от 1 до 1.8 млн.продаж для разных платформ, а 50% игр продаются в диапазонах от 100 - около 500 тыс.копий (WiiU) до 100 - 800 тыс.копий (Xbox 360).
# - Графики двух самых актуальных и преспективных платформ - Xbox One и PS4 - очень похожи. Медиана находится на отметке около 200 тыс.копий, 50% игр продаются в диапазоне 100 - ок.700 тыс.копий, порог нормальных значений - 1.55 - 1.7 млн.копий. На столько может расчитывать действительно очень качественная и успешная игра.

# %% [markdown]
# #### Влияние отзывов

# %% [markdown]
# Изучим взаимосвязь между отзывами пользователей и критиков и продажами. Для это построим диаграммы рассеяния по этим параметрам и посчитаем коэффициенты корреляции для каждой платформы.
#
# Все платформы брать нет необходимости:
# - во-первых, кое где мало оценок,
# - во-вторых, нас не интересует отжившие свое DS и PSP, а также предпоследнее поколение PS и Xbox, когда есть более актуальные.
#
# Возьмем два флагмана - PS4 и Xbox One, самую популярную портативную консоль 3DS и PC, как некую константу, которая не исчезнет. Возьмем также Wii U, как альтернативу "большим" платформам PS и Xbox

# %%
top_actual_platforms = ['PS4', 'XOne', '3DS', 'PC', 'WiiU']
for platform_name, group_data in df_actual.groupby('platform'):
    if platform_name in top_actual_platforms:
        print('Корреляция отзывов пользователей и продаж для', platform_name,  group_data['total_sales'].corr(group_data['user_score']))
        group_data.plot(kind = 'scatter', y = 'total_sales', x = 'user_score', grid = True, title = platform_name, alpha=0.5, figsize = (7, 5))
        plt.show()
        print('Корреляция отзывов критиков и продаж для', platform_name, group_data['total_sales'].corr(group_data['critic_score']))
        group_data.plot(kind = 'scatter', y = 'total_sales', x = 'critic_score',  grid = True, title = platform_name, alpha=0.5, figsize = (7, 5))
        plt.show()
# Out:
# Корреляция отзывов пользователей и продаж для 3DS 0.19758263411038596
# Корреляция отзывов критиков и продаж для 3DS 0.32080286953607845
# Корреляция отзывов пользователей и продаж для PC -0.12186747630735577
# Корреляция отзывов критиков и продаж для PC 0.23724324311567918
# Корреляция отзывов пользователей и продаж для PS4 -0.031957110204556376
# Корреляция отзывов критиков и продаж для PS4 0.406567902061781
# Корреляция отзывов пользователей и продаж для WiiU 0.4002190202148617
# Корреляция отзывов критиков и продаж для WiiU 0.3483797601201749
# Корреляция отзывов пользователей и продаж для XOne -0.06892505328279412
# Корреляция отзывов критиков и продаж для XOne 0.41699832800840175

# %% [markdown]
# По получившимся графикам можно скзать вот что:
# - Для PlayStation 4 корреляция между отзывами пользователей и продажами отрицательная и совершенно несущественная (-0.031). Отрицательное значение можно здесь объяснить тем, что чем больше игра продается, тем больше отзывов, а люди в целом склонны больше писать отрицательные отзывы, чем положительные. Хорошее они вопринимают как должное. Если все хорошо - отзывов не пишут. Хотя вообще значение настолько мало, что всерьез рассуждать о нем не стоит. А вот между отзывами критиков и продажами существует некоторая корреляция, пусть и не очень сильная, но заметная. Здесь коэффициент равен 0.406.
# - Примерно такая же картина для другой популярной платформы Xbox One: практически нет связи между отзывами пользователей и продажами (небольшой отрицательный коэффициент -0.068), но есть некоторая взаимосвязь между отзывами критиков и продажами (0.416)
# - Для WiiU прослеживается относительно других платформ сильная связь продаж и отзывов пользователей (коэффициент 0.4). Это уникально, как и то, что этот коэффициент выше, чем для связи продаж и отзывов критиков (0.348).
# - Для портативной 3DS корреляция продаж с отзывами критиков меньше, чем для "больших" платформ, хотя и не совсем нулевая (0.32). Коэффициент корреляции для отзывов пользователей и продаж больше, чем для других платформ, но все равно несущественный (0.19)
# - Наконец, для PC корреляция отзывов критиков и продаж слабая, на уровне 0.237, а для отзывов пользователей и продаж - отрицательная, но еще меньше (-0.12).
#
# Итак, в целом можно сказать, что для классических игровых приставок на продажи оказывают влияние отзывы критиков. Связь не жесткая, но заметная (на уровне около 0.4). Влияние зрительских оценок несущественное, люди продолжают покупать игры даже при негативных оценках. Точнее, скорее наоборот, чем больше игру покупают, тем больше негатива в абсолютном исчислении можно о ней услышать, независимо от ее качества. Исключение здесь WiiU, где коэффицент корреляции между отзывами пользователей и продажами 0.4. Для портативных консолей и ПК корреляция между продажами и отзывами меньше, чем для PlayStation и Xbox.
#
# Сильной связи между отзывами и продажами не наблюдается нигде. В лучшем случае отзывы лишь оказывают некоторое влияние на продажи

# %% [markdown]
# #### Жанры

# %% [markdown]
# Теперь взглянем на общее распределение игр по жанрам. Посмотрим на сумму продаж по жанрам и медианные продажи в каждом жанре

# %%
actual_genres = df_actual.pivot_table(index = 'genre', values = 'total_sales', aggfunc = ['sum', 'median'])
actual_genres.columns = ['total_sales', 'median_sales']
actual_genres.plot(kind = 'pie', y = 'total_sales', title = 'Genres',figsize = (10, 10), autopct='%1.2f%%', fontsize=10)
plt.show()
actual_genres.plot(kind = 'bar', y = 'median_sales', title = 'Genres',figsize = (15, 6), grid = True)
plt.show()
display(actual_genres)
# Out:
#               total_sales  median_sales
# genre
# Action             441.12         0.120
# Adventure           29.43         0.030
# Fighting            44.49         0.130
# Misc                85.04         0.120
# Platform            61.00         0.210
# Puzzle               4.89         0.045
# Racing              53.50         0.140
# Role-Playing       192.80         0.140
# Shooter            304.73         0.440
# Simulation          35.12         0.120
# Sports             181.07         0.240
# Strategy            13.34         0.080

# %% [markdown]
# По общему объему продаж видно:
# - безоговорочно лидирует жанр Action, занимая 30.5% всего рынка или 441.12 млн.копий.
# - В целом выделяется группа самых популярных жанров: Action (30.5%), Shooter (21.07%), Role-Playing (13.33%) и Sports (12.52%). Это 77.42% рынка. Все остальные жанры занимают не более 6% каждый.
# - Самые низкие по объему продаж жанры, это Strategy (0.92%) и Puzzle (0.34%).
#
# Если же мы взглянем на медианное количество продаж одной игры в каждом из жанров, то выяснится:
# - медианное значение количества продаж одной игры для большей части жанорв лежит в диапазоне 120 - 150 тыс.копий
# - сильно выделяется жанр шутер (свыше 400 тыс. копий), а также Sports (чуть менее 250 тыс. - это, наверное, влияние группы самый популярных игр, , и Platform (более 200 тыс.копий)
# - в аутсайдерах, как и с общими продажами - Puzzle, Strategy, Adventure
#
# В итоге:
# - жанр Shooter занимает большую долю рынка и при этом имеют большое медианное количество продаж для одной игры
# - примерно то же самое можно сказать про Sports, но его доля рынка значительно меньше. Скорее всего его показатели формируются большими играми посвященными определенному виду спорта и/или лиге с ее заголовком в названии, типа FIFA, Madden NFL, NHL, NBA и т.д. Одна такая игра продается в очень большом количестве копий, однако по сути каждая из них нишевая - для фанатов определенного вида спорта, которые при этом еще любят играть в компьютерные игры
# - жанр Action, имеющий самую большую долю рынка, при этом показывает невысокие показатели медианных продаж. Это значит, что в целом в этом жанре очень много игр, каждая из которых по отдельности - отнюдь не бестселлер.
# -  бесперспективные жанры Puzzle, Strategy, Adventure, они имеют и очень маленькю долю на рынке и маленькое медианное количество продаж

# %% [markdown]
# ## Региональные предпочтения

# %% [markdown]
# Посмотрим на региональные различия в продажах. Сначала хорошо бы понять разницу в объемах рынка, посмотрев суммарные показатели.

# %%
print('Продано в Северной Америке, 2012 - 2016 гг., млн.копий:', df_actual['na_sales'].sum())
print('Продано в Европе, 2012 - 2016 гг., млн.копий:', df_actual['eu_sales'].sum())
print('Продано в Японии, 2012 - 2016 гг., млн.копий:', df_actual['jp_sales'].sum())
print('Продано в других регионах, 2012 - 2016 гг., млн.копий:', df_actual['other_sales'].sum())
# Out:
# Продано в Северной Америке, 2012 - 2016 гг., млн.копий: 590.97
# Продано в Европе, 2012 - 2016 гг., млн.копий: 506.82000000000005
# Продано в Японии, 2012 - 2016 гг., млн.копий: 192.58
# Продано в других регионах, 2012 - 2016 гг., млн.копий: 156.16

# %% [markdown]
# Если европейский и американский рынок сопоставимы, то японский значительно меньше. Теперь посмотрим статистику по регионам

# %% [markdown]
# ### Платформы

# %% [markdown]
# Для начала взглянем на долю рынка, которую занимает каждая платформа в каждом из регионов и выделим топ-5 платформ в регионе.

# %%
region_columns = ['na_sales', 'eu_sales', 'jp_sales']
for column in region_columns:
    df_actual.pivot_table(index = 'platform', 
                          values = column, 
                          aggfunc = 'sum').plot(kind = 'pie', 
                                                y = column, 
                                                title = column,
                                                labeldistance = 0.9,
                                                figsize = (10, 10), 
                                                autopct='%1.2f%%', 
                                                fontsize=10)
    plt.show()

# %% [markdown]
# - Для североамериканского рынка лидерами являются:
#     - Xbox 360 (23.7%)
#     - PlayStation 4 (18.4%)
#     - PlayStation 3 (17.49%)
#     - Xbox One (15.76%)
#     - Nintendo 3DS (9.36%)
# - Для Европы:
#     - PlayStation 4 (27.84%)
#     - PlayStation 3 (21.08%)
#     - Xbox 360 (14.7%)
#     - Xbox One (10.18%)
#     - Nintendo 3DS (8.41%)
# - Для Японии:
#     - Nintendo 3DS (45.59%)
#     - PlayStation 3 (18.32%)
#     - PlayStation Vita (10.93%)
#     - PlayStation 4 (8.29%)
#     - Wii U (6.76%)
#
# Таким образом видно, что если североамериканский и ервопейский рынок в чем-то похожи, на них за лидерство борются два последних поколения PlayStation и Xbox, то японский кардинально отличается, во-первых, доминированием Nintendo 3DS (почти половина рынка), а, во-вторых, вообще большим вниманием к портативным консолям (3DS и PSV) и ничтожно маленькой долей Xbox.

# %% [markdown]
# ### Жанры

# %%
for column in region_columns:
    df_actual.pivot_table(index = 'genre', 
                          values = column, 
                          aggfunc = 'sum').plot(kind = 'pie', 
                                                y = column, 
                                                title = column,
                                                labeldistance = 0.9,
                                                figsize = (10, 10), 
                                                autopct='%1.2f%%', 
                                                fontsize=10)
    plt.show()

# %% [markdown]
# - Самые популярные жанры в Северной Америке:
#     - Action (30.09%)
#     - Shooter (24.5%)
#     - Sports (13.8%)
#     - Role-Playing (10.83%)
#     - Misc (6.46%)
# - В Европе:
#     - Action (31.44%)
#     - Shooter (22.39%)
#     - Sports (13.63%)
#     - Role-Playing (9.58%)
#     - Racing (5.38%)
# - В Японии:
#     - Role-Playing (33.98%)
#     - Action (27.42%)
#     - Misc (6.68%)
#     - Simulation (5.41%)
#     - Fighting (4.9%)
#
# Таким образом, как и в случае с платформами, картина рынка для жанров в Северной Америке и Европе очень похожа, вплоть до процентных долей, а вот в Японии все иначе. Во-первых, гораздо популярнее РПГ, непопулярны шутеры, и вообще, не считая большой доли игр в жанрах экшен и РПГ, доли распределены более равномерно по оставшимся жанрам.

# %% [markdown]
# ### Влияние рейтинга ESRB

# %% [markdown]
# Взглянем скольки игр с каким рейтингом вообще в наших данных

# %%
df_actual.groupby('rating').agg({'name': 'count'}).rename(columns = {'name': 'games_total'})
# Out:
#         games_total
# rating
# E               395
# E10+            306
# M               498
# T               412

# %% [markdown]
# Как видно, количество игр с разными рейтингами в целом сопоставимое, нельзя сказать, чтобы какой-то рейтинг превалировал. Теперь посмотрим, влияет ли рейтинг ESRB на продажи в разных регионах. Для это построим для каждого региона boxplot, где по оcи x - рейтинг, а по оси y - объем продаж. Сначала посмотрим общую картину

# %%
df_actual.boxplot(column = 'total_sales', by = 'rating', figsize = (15, 10))
plt.ylim (0, 2.5)
# Out:
# (0, 2.5)

# %% [markdown]
# На общем графике видно, что медианные значения игр с рейтингом М больше всех, затем идет Е10+, E и в конце - Т. Т.е. глобально игры с рейтингом Т продаются меньше - лучше уж иметь "соседние" Е10+ или М. Теперь построим графики по регионам

# %%
for column in region_columns:
    df_actual.boxplot(column = column, by = 'rating', figsize = (15, 10))
    plt.ylim (0, 1.2)

# %% [markdown]
# Для Северной Америки и Европы картина оказалась примерно похожая и повторяющая общую. Рейтинг Т - самый "невыгодный". Видимо сами тинейджеры стремятся казаться взрослее и покупают игры с рейтином М, а их родители для них, наоборот, стараются купить с рейтингом Е10+. В Японии все по-другому, но масштаб оказался неподходящим, приблизим.

# %%
df_actual.boxplot(column = 'jp_sales', by = 'rating', figsize = (15, 10))
plt.ylim (0, 0.2)
# Out:
# (0, 0.2)

# %% [markdown]
# Картина кардинально отличается - рейтинг Т - самый популярный, а медианы остальных даже не видны, рейтинг E10+ как-будто вообще не продается в Японии. У нас еще довольно много игр, не имеющих рейтинга. Посмотрим на медианы для них

# %%
for column in region_columns:
    y = df_actual.query('rating.isna()')[column].median()
    print(f'Медиана продаж игр без рейтинга для {column}: {y}')
# Out:
# Медиана продаж игр без рейтинга для na_sales: 0.0
# Медиана продаж игр без рейтинга для eu_sales: 0.0
# Медиана продаж игр без рейтинга для jp_sales: 0.03

# %% [markdown]
# Если в Америке и Европе игры без рейтинга не продаются, то в Японии медиана объема продаж для них больше, чем для всех остальных рейтингов. Вероятно, это какие-то локальные игры, которые не выходят на глобальный рынок и не оцениваются американской ESRB. Кроме того, в Японии есть специфический список популярных платформ. Портативные консоли, та же 3DS - больше для подростков. Посмотрим на количество игр с разными рейтингами для нее.

# %%
df_actual.query('platform == "3DS"').groupby('rating').agg({'name': 'count'}).rename(columns = {'name': 'games_for_ 3DS_total'})
# Out:
#         games_for_ 3DS_total
# rating
# E                         54
# E10+                      53
# M                          9
# T                         26

# %% [markdown]
# Как и следовало ожидать, очень мало игр с взрослым рейтином М.

# %% [markdown]
# Анализ данных по регионам позволяет сделать вывод о том, что европейский и североамериканский рынок в целом похожи, а вот японский имеет глубокую специфику:
# - в Северной Америке и Европе самыми популярными являются классические игровые консоли PlayStation и Xbox, в то время как в Японии очень популярны портативные платформы, и, в частности, очень большая доля DS3, а доля Xbox вообще ничтожна.
# - картина рынка для жанров в Северной Америке и Европе очень похожа, вплоть до процентных долей, а вот в Японии все иначе. Во-первых, гораздо популярнее РПГ, непопулярны шутеры, и вообще, не считая большой доли игр в жанрах экшен и РПГ, доли распределены более равномерно по оставшимся жанрам.
# - Что касается рейтинга ESRB, для Северной Америки и Европы картина оказалась примерно похожая и повторяющая общую. Рейтинг Т - самый "невыгодный", а лучше всего продаются игры с рейтингами М и Е10+. В Японии все иначе. Рейтинг Т - самый популярный. возможно это связано со специфическим предпочтениями по платформам: портативные консоли, та же 3DS - больше для подростков. При этом в Японии заметны продажи игр, не имеющих рейтинга ESRB, в то время как в США и Европе такие игры не продаются. Вероятно, существует рынок локаольных, сделанных специально в Японии и для Японии игр, не имеющих оценки.

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# Осталось проверить две гипотезы: о равенстве пользовательских рейтингов платформ Xbox One и PC и неравенстве рейтингов жанров Action и Sports

# %% [markdown]
# ### Рейтинги платформ Xbox One и PC

# %% [markdown]
# Нам нужно проверить, гипотезу, что пользовательские рейтинги для платформ Xbox One и PC одинаковые. Для этого будем использовать статистический тест о равенстве среднего двух генеральных совокупностей по взятым из них выборкам.
#
# Нулевая гипотеза будет звучать так:
# - Средние пользовательские рейтинги платформ Xbox One и PC равны
#
# Альтернативная:
# - Средние пользовательские рейтинги платформ Xbox One и PC различаются
#
# Поскольку количество игр, т.е. размер совокупностей, для каждой платформы разный, установим equal_var = False. Порог статистической значимости установим 5%. Кроме того, у нас довольно много пропусков в столбце рейтинга пользователей - надо убрать их из выборки

# %%
alpha = .05
results_xb_pc = st.ttest_ind(df_actual.query('platform == "XOne" and user_score.notna()')['user_score'], 
                             df_actual.query('platform == "PC" and user_score.notna()')['user_score'], 
                             equal_var = False)

print('p-значение: ', results_xb_pc.pvalue)

if results_xb_pc.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  0.5489537965134912
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Имеющиеся данные указывают на то, гипотеза о равенстве средних пользовательских рейтинги платформ Xbox One и PC может быть верна.

# %% [markdown]
# ### Рейтинги жанров Action и Sports

# %% [markdown]
# Теперь проверим гипотезу, что средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные. Нужно проверить гипотезу о разности, но нулевая все равно должна быть о равенстве:
# - Средние пользовательские рейтинги жанров Action и Sports равны
#
# Альтернативная гипотеза (ее нам на самом деле и надо проверить):
# - Средние пользовательские рейтинги жанров Action и Sports различаются
#
# Как и в предыдущем случае есть основания полгать что размер совокупностей, как и дисперсия, разный, поэтому надо установить equal_var = False. Порог значимости оставим тем же. И уберем игры без оценки

# %%
results_action_sports = st.ttest_ind(df_actual.query('genre == "Action" and user_score.notna()')['user_score'], 
                             df_actual.query('genre == "Sports" and user_score.notna()')['user_score'], 
                             equal_var = False)

print('p-значение: ', results_action_sports.pvalue)

if results_action_sports.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  4.24307776572644e-20
# Отвергаем нулевую гипотезу

# %% [markdown]
# P-значение чрезвычайно мало, следовательно можно отвергнуть нулевую гипотезу о равенстве рейтингов и принять альтернативную:
# - Средние пользовательские рейтинги жанров Action и Sports разные

# %% [markdown]
# ## Вывод

# %% [markdown]
# В результате исследования выяснилось:
# - Средний срок жизни одной игровой платформы - около 10 лет. Продажи игр для нее достигают пика в среднем через 4-6 после появления, а затем снижаются.
# - На 2016 год самыми перспективными платформами являются PlayStation 4 и Xbox One. Среди портативных консолей - 3DS, хотя количество продаж игр для нее снижается уже несколько лет. Доля PC остается относительно стабильной, хотя тоже немного снижается.
# - При изучении показателей продаж для самых актуальных платформ - Xbox One и PS4 - видно, что они очень похожи. Медиана находится на отметке около 200 тыс.копий, 50% игр продаются в диапазоне 100 - ок.700 тыс.копий, порог нормальных значений - . порог нормальных значений - 1.55 - 1.7 млн.копий. На столько может расчитывать действительно очень качественная и успешная игра.
# - Сильной связи между отзывами и продажами не наблюдается нигде. В лучшем случае отзывы лишь оказывают некоторое влияние на продажи. Для классических игровых приставок типа Xbox и PlayStation  cвязь между отзывами критиков и продажами не жесткая, но заметная (на уровне около 0.4). Влияние зрительских оценок несущественное. Для портативных консолей и ПК корреляция между продажами и отзывами еще меньше, чем для PlayStation и Xbox.
# - В глобальном рейтинге жанров четко выделяется группа из 4х лидеров по объемам продаж: Action (30.5%), Shooter (21.07%), Role-Playing (13.33%) и Sports (12.52%). Это 77.42% рынка. Все остальные жанры занимают не более 6% каждый. При этом по медианным количествам продаж сильно выделяется жанр Shooter (свыше 400 тыс. копий), а также Sports (чуть менее 250 тыс.) и Platform (более 200 тыс.копий). Для большинства игр медианный показатель продаж лежит в диапазоне 120 - 150 тыс.копий. В совокупности, самые "выгодные" жанр, игры в которых продаются в большом количестве копий, а сами они занимают большой процент рынка - это Shooter и Sports.
# - При изучении региональных особенностей выяснилось, что североамериканский и европейский рынок в целом похожи и отличаются нюансами, а вот японский очень специфичен. Надо сказать, что именно тенденции североамериканского и европейского рынка формируют глобальную картину, поскольку их объемы гораздо больше, чем у японского.
# - В Северной Америке и Европе наиболее популярны консоли PlayStation и Xbox двух последних поколений, а из жанров - Action, Shooter, Sports и RPG
# - В Японии картина совершенно иная - больше половины рынка занимает доля портативных консолей Nintendo 3DS и PlayStation Vita, причем 3DS доминирует на рынке безоговорочно (45.59%). Жанровая картина также отличается - в лидерах c большим отрывом RPG (33.98%) и Action (27.42%), остальные жанры занимают гораздо более скромные (менее 7%), но относительно равные ниши.
# - О влиянии рейтинга ESRB можно сказать следующее. В Северной Америке и Европе картина похожа - лучше всего продаются игры со взрослым рейтингом М, затем с E10+. В аутсайдерах промежуточный между ними рейтинг T. При этом игры без рейтинга в этих регионах не продаются. В Японии картина совершенно иная. Игры с рейтингом Т продаются значительно больше остальных. Можно предположить, что это игры для более "тинейджерских" портативных устройств, чья доля на японском рынке велика. При этом продаются и игры совсем без рейтинга, очевидно, локальные варианты.
# - Данные исследования указывают на то, что гипотезы о том, что средние пользовательские рейтинги жанров Action и Sports равны, а средние пользовательские рейтинги жанров Action и Sports различаются, верны
